# %% [markdown]
# ### In this notebook, we analyse the how the efficiency of the lepton jet reconstruction varies with decay length of the dark photon at the lab frame.

# %%
# python
import sys
import os
import importlib
from coffea import processor
# columnar analysis
from coffea.nanoevents import NanoEventsFactory
import awkward as ak   #numpy like module for handling arrays
#plotting
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
# local
sys.path.insert(1, os.path.join(sys.path[0], '../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities
# always reload local modules to pick up changes during development
importlib.reload(ffschema)  #why do we need this?
importlib.reload(sidm_processor) 
importlib.reload(utilities)
# Out:
# <module 'sidm.tools.utilities' from '/home/cms-jovyan/SIDM/sidm/studies/../../sidm/tools/utilities.py'>

# %%
samples = [
    #"2Mu2E_100GeV_5GeV_4mm",
    #"2Mu2E_150GeV_5GeV_2p7mm",
    #"2Mu2E_200GeV_5GeV_2mm",
    #"2Mu2E_500GeV_5GeV_0p8mm",
    #"2Mu2E_800GeV_5GeV_0p5mm",
    "2Mu2E_1000GeV_5GeV_0p4mm",
    "2Mu2E_1000GeV_5GeV_0p04mm",
    "2Mu2E_1000GeV_5GeV_20mm",
    "2Mu2E_1000GeV_5GeV_40mm",
    "2Mu2E_1000GeV_5GeV_4mm",
    
]
fileset = utilities.make_fileset(samples, "ffntuple_v4")

# %%
ch = "2mu2e"
runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=ffschema.FFSchema,
    #maxchunks=2,
    )

p = sidm_processor.SidmProcessor(
    [
        "baseNoLj",
        "2mu2e",
        
        
    ],
    ["base_plus_gen"]
)

output = runner.run(fileset, treename="ffNtuplizer/ffNtuple", processor_instance=p)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(20,10))
ch1 ="baseNoLj"
ch2="2mu2e"
utilities.plot([output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu_genMu_dR"][ch1,:],
                output["out"]["2Mu2E_1000GeV_5GeV_0p04mm"]["hists"]["genMu_genMu_dR"][ch1,:],
                output["out"]["2Mu2E_1000GeV_5GeV_20mm"]["hists"]["genMu_genMu_dR"][ch1,:],
                output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genMu_genMu_dR"][ch1,:],
                output["out"]["2Mu2E_1000GeV_5GeV_4mm"]["hists"]["genMu_genMu_dR"][ch1,:],],ax=ax1, density=True)
utilities.plot([output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE_genE_dR"][ch1,:],
                output["out"]["2Mu2E_1000GeV_5GeV_0p04mm"]["hists"]["genE_genE_dR"][ch1,:],
                output["out"]["2Mu2E_1000GeV_5GeV_20mm"]["hists"]["genE_genE_dR"][ch1,:],
                output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genE_genE_dR"][ch1,:],
                output["out"]["2Mu2E_1000GeV_5GeV_4mm"]["hists"]["genE_genE_dR"][ch1,:]],ax=ax2, density=True)
utilities.plot([output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu_genMu_dR"][ch2,:],
                output["out"]["2Mu2E_1000GeV_5GeV_0p04mm"]["hists"]["genMu_genMu_dR"][ch2,:],
                output["out"]["2Mu2E_1000GeV_5GeV_20mm"]["hists"]["genMu_genMu_dR"][ch2,:],
                output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genMu_genMu_dR"][ch2,:],
                output["out"]["2Mu2E_1000GeV_5GeV_4mm"]["hists"]["genMu_genMu_dR"][ch2,:],],ax=ax3, density=True)
utilities.plot([output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE_genE_dR"][ch2,:],
                output["out"]["2Mu2E_1000GeV_5GeV_0p04mm"]["hists"]["genE_genE_dR"][ch2,:],
                output["out"]["2Mu2E_1000GeV_5GeV_20mm"]["hists"]["genE_genE_dR"][ch2,:],
                output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genE_genE_dR"][ch2,:],
                output["out"]["2Mu2E_1000GeV_5GeV_4mm"]["hists"]["genE_genE_dR"][ch2,:]],ax=ax4, density=True)



ax1.legend(["2Mu2E_1000GeV_5GeV_0p4mm",
            "2Mu2E_1000GeV_5GeV_0p04mm",
            "2Mu2E_1000GeV_5GeV_20mm",
            "2Mu2E_1000GeV_5GeV_40mm",
             "2Mu2E_1000GeV_5GeV_4mm",])
ax2.legend(["2Mu2E_1000GeV_5GeV_0p4mm",
            "2Mu2E_1000GeV_5GeV_0p04mm",
            "2Mu2E_1000GeV_5GeV_20mm",
            "2Mu2E_1000GeV_5GeV_40mm",
             "2Mu2E_1000GeV_5GeV_4mm",])
ax3.legend(["2Mu2E_1000GeV_5GeV_0p4mm",
            "2Mu2E_1000GeV_5GeV_0p04mm",
            "2Mu2E_1000GeV_5GeV_20mm",
            "2Mu2E_1000GeV_5GeV_40mm",
             "2Mu2E_1000GeV_5GeV_4mm",])
ax4.legend(["2Mu2E_1000GeV_5GeV_0p4mm",
            "2Mu2E_1000GeV_5GeV_0p04mm",
            "2Mu2E_1000GeV_5GeV_20mm",
            "2Mu2E_1000GeV_5GeV_40mm",
             "2Mu2E_1000GeV_5GeV_4mm",])



ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
ax1.set_ylabel("Normalised counts")
ax2.set_ylabel("Normalised counts")
ax3.set_ylabel("Normalised counts")
ax4.set_ylabel("Normalised counts")
# Out:
# Text(0, 0.5, 'Normalised counts')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_0p04mm"]["hists"]["genE_genE_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_0p04mm"]["hists"]["genE_genE_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_0p04mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_0p04mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_0p04mm"]["hists"]["genMu_genMu_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_0p04mm"]["hists"]["genMu_genMu_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_0p04mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_0p04mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE_genE_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE_genE_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_0p4mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_0p4mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu_genMu_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu_genMu_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_0p4mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_0p4mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_4mm"]["hists"]["genE_genE_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_4mm"]["hists"]["genE_genE_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_4mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_4mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_4mm"]["hists"]["genMu_genMu_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_4mm"]["hists"]["genMu_genMu_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_4mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_4mm')

# %%
#fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(20,10))
output["out"]["2Mu2E_1000GeV_5GeV_20mm"]["hists"]["genE_genE_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_20mm"]["hists"]["genE_genE_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",)
plt.title("2Mu2E_1000GeV_5GeV_20mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_20mm')

# %%
#fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(20,10))
output["out"]["2Mu2E_1000GeV_5GeV_20mm"]["hists"]["genMu_genMu_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_20mm"]["hists"]["genMu_genMu_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",)
plt.title("2Mu2E_1000GeV_5GeV_20mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_20mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genE_genE_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genE_genE_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_40mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_40mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genMu_genMu_dR"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genMu_genMu_dR"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_40mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_40mm')

# %% [markdown]
# ## Conclusions from plotting same masses, different decay length efficiency
# ### 1) As the decay length increases, the efficiency decreases.
# ### 2) Electron pairs show more efficiency than muons.
