# %% [markdown]
# The overall purpose of this notebook is to replicate figure 1.2 from the SIDM analysis note, which plots the leading lepton pt values in a histogram. This is done for both the 2mu2e and 4mu channels, but the data sets included here do not include the 4mu channel. To do this, four new histograms were created: genE0_pt (leading electron pt from generated events), genE1_pt (subleading electron pt from the generated events), and genMu0_pt and genMu1_pt, which are the analogous plots for muons. Eventually, these plots are placed side-by-side on a logarithmic axis, replicating the figure in the analysis note.

# %%
# python
import sys
import os
import importlib
# columnar analysis
from coffea import processor
import awkward as ak
#plotting
import matplotlib.pyplot as plt

import mplhep as hep
import numpy as np
plt.style.use(hep.style.CMS)  # or ATLAS/LHCb2

# local
sys.path.insert(1, os.path.join(sys.path[0], '../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities
# always reload local modules to pick up changes during development
importlib.reload(ffschema)
importlib.reload(sidm_processor)
importlib.reload(utilities)
# Out:
# <module 'sidm.tools.utilities' from '/home/cms-jovyan/SIDM/sidm/studies/../../sidm/tools/utilities.py'>

# %%
'''
Sample names:
"SIDM_XXTo2ATo2Mu2E_mXX-100_mA-5_ctau-4"
"SIDM_XXTo2ATo2Mu2E_mXX-150_mA-5_ctau-2p7"
"SIDM_XXTo2ATo2Mu2E_mXX-200_mA-5_ctau-2"
"SIDM_XXTo2ATo2Mu2E_mXX-500_mA-5_ctau-0p8"
"SIDM_XXTo2ATo2Mu2E_mXX-800_mA-5_ctau-0p5"
"SIDM_XXTo2ATo2Mu2E_mXX-1000_mA-5_ctau-0p4"
'''
# Out:
# '\nSample names:\n"SIDM_XXTo2ATo2Mu2E_mXX-100_mA-5_ctau-4"\n"SIDM_XXTo2ATo2Mu2E_mXX-150_mA-5_ctau-2p7"\n"SIDM_XXTo2ATo2Mu2E_mXX-200_mA-5_ctau-2"\n"SIDM_XXTo2ATo2Mu2E_mXX-500_mA-5_ctau-0p8"\n"SIDM_XXTo2ATo2Mu2E_mXX-800_mA-5_ctau-0p5"\n"SIDM_XXTo2ATo2Mu2E_mXX-1000_mA-5_ctau-0p4"\n'

# %%
samples = [
    "2Mu2E_100GeV_1p2GeV_9p6mm",
    "2Mu2E_100GeV_1p2GeV_0p096mm",
    "2Mu2E_100GeV_5GeV_4mm",
    "2Mu2E_150GeV_5GeV_2p7mm",
    "2Mu2E_200GeV_5GeV_2mm",
    "2Mu2E_500GeV_5GeV_0p8mm",
    "2Mu2E_800GeV_5GeV_0p5mm",
    "2Mu2E_1000GeV_5GeV_0p4mm",
]
fileset = utilities.make_fileset(samples, "ffntuple_v4")

runner = processor.Runner(
    executor=processor.FuturesExecutor(),
    schema=ffschema.FFSchema,
)

p = sidm_processor.SidmProcessor(
    [
        "2mu2e", "4mu"
    ],
    ["base_plus_gen"]
)

output = runner.run(fileset, treename="ffNtuplizer/ffNtuple", processor_instance=p)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genE0_pt"]["2mu2e", :100j], label="genE0_pt")
hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genE_pt"]["2mu2e", :100j], label="genE_pt")
hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genE1_pt"]["2mu2e", :100j], label="genE1_pt")
plt.legend(["leading e", "all e", "subleading e"])
plt.show()

# %% [markdown]
# This code combines the density parameter with the use of subplots to place two histograms side by side. This uses two seperate samples from the runner process above. (It is also skewed because of the changes to genE0_pt binning)

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(14,5))
hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genE0_pt"]["2mu2e", :100j], ax=ax1)
hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genE_pt"]["2mu2e", :100j], ax=ax1)
hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genE1_pt"]["2mu2e", :100j], ax=ax1)

ax1.legend(["leading e", "all e", "subleading e"])

hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genE0_pt"]["2mu2e", :100j], ax=ax2)
hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genE_pt"]["2mu2e", :100j], ax=ax2)
hep.histplot(output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genE1_pt"]["2mu2e", :100j], ax=ax2)
ax2.legend(["leading e", "all e", "subleading e"])

plt.show()

# %% [markdown]
# These next few plots are variations of what was done above, but using muons found in the 2mu2e channel.

# %%
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu0_pt"]["2mu2e", :100j].plot1d()
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu_pt"]["2mu2e", :100j].plot1d()
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu1_pt"]["2mu2e", :100j].plot1d()
plt.legend(["leading mu", "all mu", "subleading mu"])
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(14,5))
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu0_pt"]["2mu2e", :100j].plot1d(ax=ax1)
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu_pt"]["2mu2e", :100j].plot1d(ax=ax1)
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu1_pt"]["2mu2e", :100j].plot1d(ax=ax1)
ax1.legend(["leading mu", "all mu", "subleading mu"])

output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genMu0_pt"]["2mu2e", :100j].plot1d(ax=ax2)
output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genMu_pt"]["2mu2e", :100j].plot1d(ax=ax2)
output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genMu1_pt"]["2mu2e", :100j].plot1d(ax=ax2)
ax2.legend(["leading mu", "all mu", "subleading mu"])

plt.show()

# %% [markdown]
# These plots attempt to use the 4mu channel, but the data sets being examined do not contain any events from there, so the histograms are empty until this can be fixed.

# %%
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu0_pt"]["4mu", :100j].plot1d()
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu_pt"]["4mu", :100j].plot1d()
plt.legend(["leading mu", "all mu"])
plt.show()
#This doesn't work beccause the sample being used only has the 2mu2e data being generated. (filename is XXTo2ATo2Mu2E)

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(14,5))
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu0_pt"]["4mu", :100j].plot1d(ax=ax1)
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu_pt"]["4mu", :100j].plot1d(ax=ax1)
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu1_pt"]["4mu", :100j].plot1d(ax=ax1)
ax1.legend(["leading mu", "all mu", "subleading mu"])

output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genMu0_pt"]["4mu", :100j].plot1d(ax=ax2)
output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genMu_pt"]["4mu", :100j].plot1d(ax=ax2)
output['out']["2Mu2E_100GeV_1p2GeV_0p096mm"]["hists"]["genMu1_pt"]["4mu", :100j].plot1d(ax=ax2)
ax2.legend(["leading mu", "all mu", "subleading mu"])

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(16,5))
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genE0_pt"]["2mu2e", :100j].plot1d(ax=ax1)
ax1.set_xlabel("genE0_pt on 2mu2e")
ax1.set_ylabel("Weighted Events")
output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu0_pt"]["2mu2e", :100j].plot1d(ax=ax2)
ax2.set_xlabel("genMu0_pt on 2mu2e")

output['out']["2Mu2E_100GeV_1p2GeV_9p6mm"]["hists"]["genMu0_pt"]["4mu", :100j].plot1d(ax=ax3)
ax3.set_xlabel("genMu0_pt on 4mu channel")
# Out:
# Text(1, 0, 'genMu0_pt on 4mu channel')

# %%
output['out']["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genE0_pt"]["2mu2e", :100j].plot1d()
output['out']["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genE0_pt"]["2mu2e", :100j].plot1d()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f830ef1d9d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %% [markdown]
# These plots replicate what was found in the analysis note. The first set of three show the leading electron and muon pt in the 2mu2e channel, and the next graphs show the same data on a log scale, as it is shown in the AN. The 4mu data is still left out.

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(16,5))
hep.histplot(output['out']["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :600j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :600j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :600j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :600j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :600j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :600j], ax=ax1, density=True)
ax1.set_xlabel("genE0_pt on 2mu2e")
ax1.set_ylabel("Weighted Events")
#ax1.legend(["mXX-100", "mXX-150", "mXX-200", "mXX-500", "mXX-800", "mXX-1000"])

hep.histplot(output['out']["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :600j], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :600j], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :600j], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :600j], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :600j], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :600j], ax=ax2, density=True)
ax2.set_xlabel("genMu0_pt on 2mu2e")
ax2.set_ylabel("Weighted Events")
#ax2.legend(["mXX-100", "mXX-150", "mXX-200", "mXX-500", "mXX-800", "mXX-1000"])
# Out:
# Text(0, 1, 'Weighted Events')

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(10,9))
hep.histplot(output['out']["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :1000j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :1000j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :1000j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :1000j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :1000j], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :1000j], ax=ax1, density=True)
ax1.set_xlabel("genE0_pt on 2mu2e")
ax1.set_ylabel("Weighted Events")
ax1.set_yscale("log")
ax1.legend(["mXX = 100 GeV", "mXX = 150 GeV", "mXX = 200 GeV", "mXX = 500 GeV", "mXX = 800 GeV", "mXX = 1000 GeV"])

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(10,9))
hep.histplot(output['out']["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
ax1.set_xlabel("genMu0_pt on 2mu2e")
ax1.set_ylabel("Weighted Events")
ax1.set_yscale("log")
ax1.legend(["mXX-100", "mXX-150", "mXX-200", "mXX-500", "mXX-800", "mXX-1000"])

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(16,7))
hep.histplot(output['out']["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
hep.histplot(output['out']["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE0_pt_highRange"]["2mu2e", :], ax=ax1, density=True)
ax1.set_xlabel("genE0_pt on 2mu2e", fontsize=18)
ax1.set_ylabel("Normalized Counts / 10 GeV", fontsize=18)
ax1.set_yscale("log")
ax1.legend(["mXX = 100 GeV", "mXX = 150 GeV", "mXX = 200 GeV", "mXX = 500 GeV", "mXX = 800 GeV", "mXX = 1000 GeV"], fontsize=12)
hep.cms.text("Simulation", ax=ax1, fontsize=20)

hep.histplot(output['out']["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax2, density=True)
hep.histplot(output['out']["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu0_pt_highRange"]["2mu2e", :], ax=ax2, density=True)
ax2.set_xlabel("genMu0_pt on 2mu2e", fontsize=18)
ax2.set_ylabel("Normalized Counts / 10 GeV", fontsize=18)
ax2.set_yscale("log")
ax2.legend(["mXX = 100 GeV", "mXX = 150 GeV", "mXX = 200 GeV", "mXX = 500 GeV", "mXX = 800 GeV", "mXX = 1000 GeV"], fontsize=12)
hep.cms.text("Simulation", ax=ax2, fontsize=20)
# Out:
# (exptext: Custom Text(0.001, 1, 'CMS'),
#  expsuffix: Custom Text(0.001, 1.005, 'Simulation'))

# %% [markdown]
# These graphs are very similar to those in figure 2 of the analysis note. All of these data sets hold the mass of the dark photon (A) at 5 GeV.
