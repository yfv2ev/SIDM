# %% [markdown]
# ### In this noteboof, we see the efficiency of reconstruction of lepton jet based on the lepton Pt. The sample files used has dark matter bound state varied from 100 to 1000Gev, dark photon mass kept at 5GeV and decay length at the lab frame at 3cm

# %%
# python
import sys
import os
import importlib
from coffea import processor
# columnar analysis
from coffea.nanoevents import NanoEventsFactory
import awkward as ak   #numpy like module for handling arrays
#plotting
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
# local
sys.path.insert(1, os.path.join(sys.path[0], '../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities
# always reload local modules to pick up changes during development
importlib.reload(ffschema)  #why do we need this?
importlib.reload(sidm_processor) 
importlib.reload(utilities)
# Out:
# <module 'sidm.tools.utilities' from '/home/cms-jovyan/SIDM/sidm/studies/../../sidm/tools/utilities.py'>

# %%
samples = [
    "2Mu2E_100GeV_5GeV_4mm",
    "2Mu2E_150GeV_5GeV_2p7mm",
    "2Mu2E_200GeV_5GeV_2mm",
    "2Mu2E_500GeV_5GeV_0p8mm",
    "2Mu2E_800GeV_5GeV_0p5mm",
    "2Mu2E_1000GeV_5GeV_0p4mm",
    #"2Mu2E_1000GeV_5GeV_0p04mm",
    #"2Mu2E_1000GeV_5GeV_20mm",
    #"2Mu2E_1000GeV_5GeV_40mm",
   # "2Mu2E_1000GeV_5GeV_4mm",
    
]
fileset = utilities.make_fileset(samples, "ffntuple_v4")

# %%
runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=ffschema.FFSchema,
    #maxchunks=2,
    )

p = sidm_processor.SidmProcessor(
    [
        "no_lj_selection",
        "2mu2e",
        
        
    ],
    ["base_plus_gen"]
)

output = runner.run(fileset, treename="ffNtuplizer/ffNtuple", processor_instance=p)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# ...
# 'weight']
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(16,7))
ch1 ="no_lj_selection"
ch2="2mu2e"
utilities.plot([output["out"][f"{name}"]["hists"]["genE_pt_highRange"][ch1,:] for name in samples], ax=ax1, density=True)
utilities.plot([output["out"][f"{name}"]["hists"]["genMu_pt_highRange"][ch1,:] for name in samples], ax=ax2, density=True)
ax1.legend(samples)
ax2.legend(samples)

ax1.set_yscale('log')
ax2.set_yscale('log')
ax1.set_ylabel("Normalised counts")
ax2.set_ylabel("Normalised counts")
plt.suptitle(r"Pt for No selection")
# Out:
# Text(0.5, 0.98, 'Pt for No selection')

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(16,7))

utilities.plot([output["out"][f"{name}"]["hists"]["genE_pt_highRange"][ch2,:] for name in samples], ax=ax1, density=True)
utilities.plot([output["out"][f"{name}"]["hists"]["genMu_pt_highRange"][ch2,:] for name in samples], ax=ax2, density=True)
ax1.legend(samples)
ax2.legend(samples)

ax1.set_yscale('log')
ax2.set_yscale('log')
ax1.set_ylabel("Normalised counts")
ax2.set_ylabel("Normalised counts")
plt.suptitle(r"Pt for leptons in 2mu2e channel ")
# Out:
# Text(0.5, 0.98, 'Pt for leptons in 2mu2e channel ')

# %%
output["out"]["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genE_pt_highRange"][ch2,:115j].plot_ratio(
       output["out"]["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genE_pt_highRange"][ch1,:115j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_100GeV_5GeV_4mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_100GeV_5GeV_4mm')

# %%
output["out"]["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genMu_pt_highRange"][ch2,:115j].plot_ratio(
       output["out"]["2Mu2E_100GeV_5GeV_4mm"]["hists"]["genMu_pt_highRange"][ch1,:115j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_100GeV_5GeV_4mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_100GeV_5GeV_4mm')

# %%
output["out"]["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genE_pt_highRange"][ch2,:200j].plot_ratio(
       output["out"]["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genE_pt_highRange"][ch1,:200j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_150GeV_5GeV_2p7mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_150GeV_5GeV_2p7mm')

# %%
output["out"]["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genMu_pt_highRange"][ch2,:200j].plot_ratio(
       output["out"]["2Mu2E_150GeV_5GeV_2p7mm"]["hists"]["genMu_pt_highRange"][ch1,:200j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_150GeV_5GeV_2p7mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_150GeV_5GeV_2p7mm')

# %%
output["out"]["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genE_pt_highRange"][ch2,:200j].plot_ratio(
       output["out"]["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genE_pt_highRange"][ch1,:200j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_200GeV_5GeV_2mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_200GeV_5GeV_2mm')

# %%
output["out"]["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genMu_pt_highRange"][ch2,:200j].plot_ratio(
       output["out"]["2Mu2E_200GeV_5GeV_2mm"]["hists"]["genMu_pt_highRange"][ch1,:200j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_200GeV_5GeV_2mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_200GeV_5GeV_2mm')

# %%
output["out"]["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genE_pt_highRange"][ch2,:350j].plot_ratio(
       output["out"]["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genE_pt_highRange"][ch1,:350j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_500GeV_5GeV_0p8mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_500GeV_5GeV_0p8mm')

# %%
output["out"]["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genMu_pt_highRange"][ch2,:350j].plot_ratio(
       output["out"]["2Mu2E_500GeV_5GeV_0p8mm"]["hists"]["genMu_pt_highRange"][ch1,:350j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_500GeV_5GeV_0p8mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_500GeV_5GeV_0p8mm')

# %%
output["out"]["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genE_pt_highRange"][ch2,:500j].plot_ratio(
       output["out"]["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genE_pt_highRange"][ch1,:500j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_800GeV_5GeV_0p5mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_800GeV_5GeV_0p5mm')

# %%
output["out"]["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genMu_pt_highRange"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_800GeV_5GeV_0p5mm"]["hists"]["genMu_pt_highRange"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_800GeV_5GeV_0p5mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_800GeV_5GeV_0p5mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE_pt_highRange"][ch2,:635j].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genE_pt_highRange"][ch1,:635j], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_0p4mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_0p4mm')

# %%
output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu_pt_highRange"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_0p4mm"]["hists"]["genMu_pt_highRange"][ch1,:], 
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.title("2Mu2E_1000GeV_5GeV_0p4mm")
# Out:
# Text(0.5, 1.0, '2Mu2E_1000GeV_5GeV_0p4mm')
