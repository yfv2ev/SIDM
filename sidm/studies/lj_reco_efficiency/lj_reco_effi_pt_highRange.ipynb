# %% [markdown]
# In this notebook I will plot the lepton jet reconstruction efficiency w.r.t $p_T$ for higher range. We will consider both highly collimated and least collimated dark photons. I will consider the sample with decay length at the lab frame as 300cm. To consider a higher $p_T$ I am considering the sample with higher bound state mass of 1000 GeV.

# %%
# python
import sys
import os
import importlib
from coffea import processor
# columnar analysis
from coffea.nanoevents import NanoEventsFactory
import awkward as ak   #numpy like module for handling arrays
#plotting
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
# local
sys.path.insert(1, os.path.join(sys.path[0], '../../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities
# always reload local modules to pick up changes during development
importlib.reload(ffschema)  #why do we need this?
importlib.reload(sidm_processor) 
importlib.reload(utilities)
# Out:
# <module 'sidm.tools.utilities' from '/home/cms-jovyan/SIDM/sidm/studies/lj_reco_efficiency/../../../sidm/tools/utilities.py'>

# %%
samples = [

    "2Mu2E_1000GeV_5GeV_40mm",
    "2Mu2E_1000GeV_0p25GeV_2mm",
    #"2Mu2E_1000GeV_5GeV_20mm",
    #"2Mu2E_1000GeV_5GeV_40mm",
   # "2Mu2E_1000GeV_5GeV_4mm",
    
]
fileset = utilities.make_fileset(samples, "ffntuple_v4")

# %%
runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=ffschema.FFSchema,
    #maxchunks=2,
    )

p = sidm_processor.SidmProcessor(
    [
        "baseNoLj",
        "baseNoLj_lowLxyA",
        "baseNoLj_Lxy_upto250A",
        "baseNoLj_eLj",
        "baseNoLj_gLj", 
        "baseNoLj_dsaMuLj",
        "baseNoLj_pfMuLj",
        
        
    ],
    ["base_plus_gen"]
)

output = runner.run(fileset, treename="ffNtuplizer/ffNtuple", processor_instance=p)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# Not applying any cuts to the lepton jets for channel  baseNoLj
# Not applying any cuts to the lepton jets for channel  baseNoLj_lowLxyA
# Not applying any cuts to the lepton jets for channel  baseNoLj_Lxy_upto250A
# ...
# 'weight']
# Not applying any cuts to the lepton jets for channel  baseNoLj
# Not applying any cuts to the lepton jets for channel  baseNoLj_lowLxyA
# Not applying any cuts to the lepton jets for channel  baseNoLj_Lxy_upto250A
# ...
# 'weight']
# Not applying any cuts to the lepton jets for channel  baseNoLj
# Not applying any cuts to the lepton jets for channel  baseNoLj_lowLxyA
# Not applying any cuts to the lepton jets for channel  baseNoLj_Lxy_upto250A
# ...
# 'weight']
# ...

# %%
ch1= "baseNoLj"
ch2= "baseNoLj_lowLxyA"
ch3= "baseNoLj_Lxy_upto250A"
ch4= "baseNoLj_eLj"
ch5= "baseNoLj_gLj" 
ch6= "baseNoLj_dsaMuLj"
ch7= "baseNoLj_pfMuLj"

# %% [markdown]
# ### 0.25 GeV

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toE_matched_egmLj_pt_highRange"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toE_pt_highRange"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_0.25_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toE_matched_egmLj_pt_highRange"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toE_pt_highRange"][ch2,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_0.25_pt_highrange_lxy_cut.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toMu_matched_muLj_pt_highRange"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_pt_highRange"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_0.25_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toMu_matched_muLj_pt_highRange"][ch3,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_pt_highRange"][ch3,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.savefig("../../../plots/Zd_mumu_1000_0.25_pt_highrange_lxycut.png", bbox_inches="tight")

# %% [markdown]
# ### 5GeV

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toE_matched_egmLj_pt_highRange"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toE_pt_highRange"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_5_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toE_matched_egmLj_pt_highRange"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toE_pt_highRange"][ch2,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_5_pt_highrange_lxycut.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toMu_matched_muLj_pt_highRange"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_pt_highRange"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toMu_matched_muLj_pt_highRange"][ch3,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_pt_highRange"][ch3,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_pt_highrange_lxycut.png", bbox_inches="tight")

# %% [markdown]
# Now we consider the $L_{xy}$ distribution for both the samples.

# %% [markdown]
# ### 0.25 GeV

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toE_matched_egmLj_lxy"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toE_lxy"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_0.25_lxy.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toE_matched_egmLj_lxy"][ch4,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toE_lxy"][ch4,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_0.25_lxy_etype.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toE_matched_egmLj_lxy"][ch5,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toE_lxy"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_0.25_lxy_gammatype.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toMu_matched_muLj_lxy"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_lxy"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_0.25_lxy.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toMu_matched_muLj_lxy"][ch6,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_lxy"][ch6,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_0.25_lxy_dsa.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genA_toMu_matched_muLj_lxy"][ch7,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_lxy"][ch7,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_0.25_lxy_pf.png", bbox_inches="tight")

# %% [markdown]
# ### 5 GeV

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toE_matched_egmLj_lxy"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toE_lxy"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_5_lxy.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toE_matched_egmLj_lxy"][ch4,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toE_lxy"][ch4,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_5_lxy_etype.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toE_matched_egmLj_lxy"][ch5,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toE_lxy"][ch5,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_ee_1000_5_lxy_gammatype.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toMu_matched_muLj_lxy"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_lxy"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_lxy.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toMu_matched_muLj_lxy"][ch6,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_lxy"][ch6,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_lxy_dsa.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genA_toMu_matched_muLj_lxy"][ch7,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_lxy"][ch7,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_lxy_pf.png", bbox_inches="tight")
