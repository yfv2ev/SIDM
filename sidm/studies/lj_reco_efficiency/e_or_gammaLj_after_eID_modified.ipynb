# %%
# python
import sys
import os
import importlib
from coffea import processor
# columnar analysis
from coffea.nanoevents import NanoEventsFactory
import awkward as ak   #numpy like module for handling arrays

# local
sys.path.insert(1, os.path.join(sys.path[0], '../../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities, scaleout
# always reload local modules to pick up changes during development
importlib.reload(ffschema)  #why do we need this?
importlib.reload(sidm_processor) 
importlib.reload(utilities)
# plotting
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import hist
utilities.set_plot_style()
# %matplotlib inline

# %%
samples = [
  
    "2Mu2E_200GeV_0p25GeV_10mm",
    "2Mu2E_200GeV_1p2GeV_48mm",
    "2Mu2E_200GeV_5GeV_200mm",
 
    
]
fileset = utilities.make_fileset(samples, "ffntuple_v4")

channels = [
     
       "baseNoLj_eLj_eIdBit2to8",
       "baseNoLj_eLj",
       "baseNoLj_gLj_eIdBit2to8",
       "baseNoLj_gLj",
       "baseNoLj_eAndGLj_eIdBit2to8",
       "baseNoLj_eAndGLj",
    
        
    ]
runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=ffschema.FFSchema,
    #maxchunks=1,
    )

p = sidm_processor.SidmProcessor(
    channels,
    ["gen_base", 
    #"lepton_genLepton_base",
     "electron_base",
     "lj_base",
    ], 
     lj_reco_choices = [ "0.4"],
)

output = runner.run(fileset, treename="ffNtuplizer/ffNtuple", processor_instance=p)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# #--------------------------------------------------------------------------
# #                         FastJet release 3.4.0
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# ...

# %%
ch2 = "baseNoLj_eLj_eIdBit2to8"
ch1 = "baseNoLj_eLj"
ch4 = "baseNoLj_gLj_eIdBit2to8"
ch3 = "baseNoLj_gLj"
ch6 = "baseNoLj_eAndGLj_eIdBit2to8"
ch5 =  "baseNoLj_eAndGLj"

# %%
fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch2,::1j]
den_after = hists["genAs_toE_lxy"][ch2,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch1,::1j]
den_before = hists["genAs_toE_lxy"][ch1,::1j]
utilities.plot(num_before, label = ch1 + "matched")
utilities.plot(num_after, label = ch2 + "matched")
utilities.plot(den_before, label = ch1)
utilities.plot(den_after, label = ch2)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_5GeV_200mm", fontsize=30)


fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch2,::1j]
den_after = hists["genAs_toE_lxy"][ch2,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch1,::1j]
den_before = hists["genAs_toE_lxy"][ch1,::1j]
utilities.plot(num_before, label = ch1 + "matched")
utilities.plot(num_after, label = ch2 + "matched")
utilities.plot(den_before, label = ch1)
utilities.plot(den_after, label = ch2)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_1p2GeV_48mm", fontsize=30)


fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch2,::1j]
den_after = hists["genAs_toE_lxy"][ch2,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch1,::1j]
den_before = hists["genAs_toE_lxy"][ch1,::1j]
utilities.plot(num_before, label = ch1 + "matched")
utilities.plot(num_after, label = ch2 + "matched")
utilities.plot(den_before, label = ch1)
utilities.plot(den_after, label = ch2)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_0p25GeV_10mm", fontsize=30)
# Out:
# Text(0.5, 0.98, '2Mu2E_200GeV_0p25GeV_10mm')

# %%
fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch4,::1j]
den_after = hists["genAs_toE_lxy"][ch4,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch3,::1j]
den_before = hists["genAs_toE_lxy"][ch3,::1j]
utilities.plot(num_before, label = ch3 + "matched")
utilities.plot(num_after, label = ch4 + "matched")
utilities.plot(den_before, label = ch3)
utilities.plot(den_after, label = ch4)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_5GeV_200mm", fontsize=30)


fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch4,::1j]
den_after = hists["genAs_toE_lxy"][ch4,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch3,::1j]
den_before = hists["genAs_toE_lxy"][ch3,::1j]
utilities.plot(num_before, label = ch3 + "matched")
utilities.plot(num_after, label = ch4 + "matched")
utilities.plot(den_before, label = ch3)
utilities.plot(den_after, label = ch4)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_1p2GeV_48mm", fontsize=30)


fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch4,::1j]
den_after = hists["genAs_toE_lxy"][ch4,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch3,::1j]
den_before = hists["genAs_toE_lxy"][ch3,::1j]
utilities.plot(num_before, label = ch3 + "matched")
utilities.plot(num_after, label = ch4 + "matched")
utilities.plot(den_before, label = ch3)
utilities.plot(den_after, label = ch4)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_0p25GeV_10mm", fontsize=30)
# Out:
# Text(0.5, 0.98, '2Mu2E_200GeV_0p25GeV_10mm')

# %%
fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]
plt.subplot(1, 2, 1)
hists["genA_toE_matched_egmLj_lxy"][ch6,::1j].plot()
hists["genA_toE_matched_egmLj_lxy"][ch5,::1j].plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f302467e8b0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch6,::1j]
den_after = hists["genAs_toE_lxy"][ch6,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch5,::1j]
den_before = hists["genAs_toE_lxy"][ch5,::1j]
utilities.plot(num_before, label = ch5 + "matched")
utilities.plot(num_after, label = ch6 + "matched")
utilities.plot(den_before, label = ch5)
utilities.plot(den_after, label = ch6)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_5GeV_200mm", fontsize=30)


fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch6,::1j]
den_after = hists["genAs_toE_lxy"][ch6,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch5,::1j]
den_before = hists["genAs_toE_lxy"][ch5,::1j]
utilities.plot(num_before, label = ch5 + "matched")
utilities.plot(num_after, label = ch6 + "matched")
utilities.plot(den_before, label = ch5)
utilities.plot(den_after, label = ch6)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_1p2GeV_48mm", fontsize=30)


fig , ax =plt.subplots(1,2, figsize =(2*12, 10))
hists = output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]
plt.subplot(1, 2, 1)
num_after = hists["genA_toE_matched_egmLj_lxy"][ch6,::1j]
den_after = hists["genAs_toE_lxy"][ch6,::1j]
num_before = hists["genA_toE_matched_egmLj_lxy"][ch5,::1j]
den_before = hists["genAs_toE_lxy"][ch5,::1j]
utilities.plot(num_before, label = ch5 + "matched")
utilities.plot(num_after, label = ch6 + "matched")
utilities.plot(den_before, label = ch5)
utilities.plot(den_after, label = ch6)
plt.legend()
plt.subplot(1, 2, 2)
eff_before, errors_before = utilities.get_eff_hist(num_before, den_before)
eff_after, errors_after = utilities.get_eff_hist(num_after, den_after)
utilities.plot(eff_before, yerr = errors_before, label = "Before Electron ID Modification")
utilities.plot(eff_after, yerr = errors_after, label = "After Electron ID Modification")
plt.legend()
fig.suptitle("2Mu2E_200GeV_0p25GeV_10mm", fontsize=30)
# Out:
# Text(0.5, 0.98, '2Mu2E_200GeV_0p25GeV_10mm')

# %%
hists = output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]

# %%
fig , ax =plt.subplots(1,3, figsize =(3*12, 10))
hists = output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]
plt.subplot(1, 3, 1)
utilities.plot(hists["egm_lj_pt"][ch1,:], label = ch1 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch2,:], label = ch2 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch1,:], label = ch1 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch2,:], label = ch2 + "_genAs_toE_pt_matched")
plt.legend()

plt.subplot(1, 3, 2)

utilities.plot(hists["egm_lj_pt"][ch3,:], label = ch3 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch4,:], label = ch4 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch3,:], label = ch3 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch4,:], label = ch4 + "_genAs_toE_pt_matched")
plt.legend()
plt.subplot(1, 3, 3)


utilities.plot(hists["egm_lj_pt"][ch5,:], label = ch5 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch6,:], label = ch6 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch5,:], label = ch5 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch6,:], label = ch6 + "_genAs_toE_pt_matched")
plt.legend()
plt.suptitle("2Mu2E_200GeV_0p25GeV_10mm")
# Out:
# Text(0.5, 0.98, '2Mu2E_200GeV_0p25GeV_10mm')

# %%
fig , ax =plt.subplots(1,3, figsize =(3*12, 10))
hists = output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]
plt.subplot(1, 3, 1)
utilities.plot(hists["egm_lj_pt"][ch1,:], label = ch1 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch2,:], label = ch2 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch1,:], label = ch1 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch2,:], label = ch2 + "_genAs_toE_pt_matched")
plt.legend()

plt.subplot(1, 3, 2)

utilities.plot(hists["egm_lj_pt"][ch3,:], label = ch3 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch4,:], label = ch4 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch3,:], label = ch3 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch4,:], label = ch4 + "_genAs_toE_pt_matched")
plt.legend()
plt.subplot(1, 3, 3)


utilities.plot(hists["egm_lj_pt"][ch5,:], label = ch5 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch6,:], label = ch6 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch5,:], label = ch5 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch6,:], label = ch6 + "_genAs_toE_pt_matched")
plt.legend()
plt.suptitle("2Mu2E_200GeV_1p2GeV_48mm")
# Out:
# Text(0.5, 0.98, '2Mu2E_200GeV_1p2GeV_48mm')

# %%
fig , ax =plt.subplots(1,3, figsize =(3*12, 10))
hists = output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]
plt.subplot(1, 3, 1)
utilities.plot(hists["egm_lj_pt"][ch1,:], label = ch1 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch2,:], label = ch2 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch1,:], label = ch1 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch2,:], label = ch2 + "_genAs_toE_pt_matched")
plt.legend()

plt.subplot(1, 3, 2)

utilities.plot(hists["egm_lj_pt"][ch3,:], label = ch3 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch4,:], label = ch4 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch3,:], label = ch3 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch4,:], label = ch4 + "_genAs_toE_pt_matched")
plt.legend()
plt.subplot(1, 3, 3)


utilities.plot(hists["egm_lj_pt"][ch5,:], label = ch5 + "_egm_lj_pt")
utilities.plot(hists["egm_lj_pt"][ch6,:], label = ch6 + "_egm_lj_pt")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch5,:], label = ch5 + "_genAs_toE_pt_matched")
utilities.plot(hists["genA_toE_matched_egmLj_pt"][ch6,:], label = ch6 + "_genAs_toE_pt_matched")
plt.legend()
plt.suptitle("2Mu2E_200GeV_5GeV_200mm")
# Out:
# Text(0.5, 0.98, '2Mu2E_200GeV_5GeV_200mm')
