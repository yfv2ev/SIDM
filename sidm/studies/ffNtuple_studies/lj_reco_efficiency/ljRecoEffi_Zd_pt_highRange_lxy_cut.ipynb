# %%
# python
import sys
import os
import importlib
from coffea import processor
# columnar analysis
from coffea.nanoevents import NanoEventsFactory
import awkward as ak   #numpy like module for handling arrays
#plotting
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
# local
sys.path.insert(1, os.path.join(sys.path[0], '../../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities
# always reload local modules to pick up changes during development
importlib.reload(ffschema)  #why do we need this?
importlib.reload(sidm_processor) 
importlib.reload(utilities)
# Out:
# <module 'sidm.tools.utilities' from '/home/cms-jovyan/SIDM/sidm/studies/lj_reco_efficiency/../../../sidm/tools/utilities.py'>

# %%
samples = [

    "2Mu2E_1000GeV_5GeV_40mm",
    "2Mu2E_1000GeV_0p25GeV_2mm",
    #"2Mu2E_1000GeV_5GeV_20mm",
    #"2Mu2E_1000GeV_5GeV_40mm",
   # "2Mu2E_1000GeV_5GeV_4mm",
    
]
fileset = utilities.make_fileset(samples, "ffntuple_v4")

# %%
runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=ffschema.FFSchema,
    #maxchunks=2,
    )

p = sidm_processor.SidmProcessor(
    [
        "baseNoLj",
        "baseNoLj_lowLxyA",
        "baseNoLj_Lxy_upto250A",
        "baseNoLj_promptA",
        "baseNoLj_displacedA", 
        "baseNoLj_veryDisplacedA",
        
        
        
    ],
    ["base_plus_gen"]
)

output = runner.run(fileset, treename="ffNtuplizer/ffNtuple", processor_instance=p)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# Not applying any cuts to the lepton jets for channel  baseNoLj
# Not applying any cuts to the lepton jets for channel  baseNoLj_lowLxyA
# Not applying any cuts to the lepton jets for channel  baseNoLj_Lxy_upto250A
# Not applying any cuts to the lepton jets for channel  baseNoLj_promptA
# Not applying any cuts to the lepton jets for channel  baseNoLj_displacedA
# Not applying any cuts to the lepton jets for channel  baseNoLj_veryDisplacedA
# ...
# 'weight']
# Not applying any cuts to the lepton jets for channel  baseNoLj
# Not applying any cuts to the lepton jets for channel  baseNoLj_lowLxyA
# Not applying any cuts to the lepton jets for channel  baseNoLj_Lxy_upto250A
# ...

# %%
ch1= "baseNoLj"
ch2= "baseNoLj_lowLxyA"
ch3= "baseNoLj_Lxy_upto250A"
ch4= "baseNoLj_promptA"
ch5= "baseNoLj_displacedA"
ch6= "baseNoLj_veryDisplacedA"

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_pt_highRange"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.savefig("../../../plots/Zd_mumu_1000_0.25_pt_highrange_lxycut.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch2,100j:600j].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_pt_highRange"][ch2,100j:600j], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.savefig("../../../plots/Zd_mumu_1000_0.25_pt_highrange_lxycut.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch3,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_pt_highRange"][ch3,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.savefig("../../../plots/Zd_mumu_1000_0.25_pt_highrange_lxycut.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch4,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_pt_highRange"][ch4,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.savefig("../../../plots/Zd_mumu_1000_0.25_pt_highrange_lxycut.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch5,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_pt_highRange"][ch5,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.savefig("../../../plots/Zd_mumu_1000_0.25_pt_highrange_lxycut.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch6,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_0p25GeV_2mm"]["hists"]["genAs_toMu_pt_highRange"][ch6,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
plt.savefig("../../../plots/Zd_mumu_1000_0.25_pt_highrange_lxycut.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch1,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_pt_highRange"][ch1,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch2,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_pt_highRange"][ch2,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch3,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_pt_highRange"][ch3,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch4,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_pt_highRange"][ch4,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch5,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_pt_highRange"][ch5,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_pt_highrange.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_matched_muLj_pt_highRange"][ch6,:].plot_ratio(
       output["out"]["2Mu2E_1000GeV_5GeV_40mm"]["hists"]["genAs_toMu_pt_highRange"][ch6,:], 
       rp_num_label=r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow \mu\mu $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency",
       )
plt.savefig("../../../plots/Zd_mumu_1000_5_pt_highrange.png", bbox_inches="tight")
