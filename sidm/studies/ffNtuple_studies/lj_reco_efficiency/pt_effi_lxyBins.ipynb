# %%
# python
import sys
import os
import importlib
from coffea import processor
# columnar analysis
from coffea.nanoevents import NanoEventsFactory
import awkward as ak   #numpy like module for handling arrays

# local
sys.path.insert(1, os.path.join(sys.path[0], '../../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities, scaleout
# always reload local modules to pick up changes during development
importlib.reload(ffschema)  #why do we need this?
importlib.reload(sidm_processor) 
importlib.reload(utilities)
# plotting
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import hist
utilities.set_plot_style()
# %matplotlib inline

# %%
samples = [
    #"2Mu2E_100GeV_5GeV_400mm",
    #"2Mu2E_100GeV_5GeV_0p4mm",
    #"2Mu2E_150GeV_5GeV_2p7mm",
    "2Mu2E_200GeV_0p25GeV_10mm",
     "2Mu2E_200GeV_5GeV_200mm",
      "2Mu2E_200GeV_1p2GeV_48mm",
    #"2Mu2E_500GeV_5GeV_80mm",
    #"2Mu2E_800GeV_5GeV_0p5mm",
    #"2Mu2E_1000GeV_5GeV_0p4mm",
    #"2Mu2E_1000GeV_5GeV_0p04mm",
    #"2Mu2E_1000GeV_5GeV_20mm",
    #"2Mu2E_100GeV_1p2GeV_9p6mm",
    #"2Mu2E_1000GeV_5GeV_40mm",
    #"2Mu2E_100GeV_p25GeV_400mm",
   # "2Mu2E_1000GeV_5GeV_4mm",
    
]
fileset = utilities.make_fileset(samples, "ffntuple_v4")

# %%
runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=ffschema.FFSchema,
    #maxchunks=2,
    )

p = sidm_processor.SidmProcessor(
    [
        #"baseNoLj",
        #"baseNoLj_A_ee_matched_lj",
        #"baseNoLj_A_mumu_matched_lj"
        #"baseNoLj_A_ee_highPtA_lowLxyA",
        #"baseNoLj_A_ee_matched_lj_highPT_lowLxyA",
        #"baseNoLj_A_mumu_highPtA_lowLxyA",
        #"baseNoLj_A_mumu_matched_lj_highPT_lowLxyA",
        #"baseNoLj_promptA",
        #"baseNoLj_displacedA",
        #"baseNoLj_veryDisplacedA",
        #"baseNoLj_lowLxyA",
        #"baseNoLj_highPtA",
        "baseNoLj_A_ee_highPtA_Lxyto5A",
        "baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A",
        "baseNoLj_A_ee_highPtA_Lxy40to77A",
        "baseNoLj_A_ee_highPtA_Lxy40to77A",
        "baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A",
        "baseNoLj_A_ee_highPtA_Lxy125to135A",
        "baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A",
        #"baseNoLj_Lxy_upto250A",
        #"2mu2e",
        
        
    ],
    ["gen_base", 
     #"lj_base",
    ]
)

output = runner.run(fileset, treename="ffNtuplizer/ffNtuple", processor_instance=p)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxyto5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_highPtA_Lxy125to135A
# Not applying any cuts to the lepton jets for channel  baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
ch1 = "baseNoLj_highPtA"
ch2 = "baseNoLj_A_ee_highPtA_Lxyto5A"
ch3 = "baseNoLj_A_ee_matched_lj_highPT_Lxy0to5A"
ch4 = "baseNoLj_A_ee_highPtA_Lxy40to77A"
ch5 = "baseNoLj_A_ee_matched_lj_highPT_Lxy40to77A"
ch6 = "baseNoLj_A_ee_highPtA_Lxy125to135A"
ch7 = "baseNoLj_A_ee_matched_lj_highPT_Lxy125to135A"

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]["genAs_toE_pt"][ch3,:].plot_ratio(
       output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]["genAs_toE_pt"][ch2,:], 
      rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm"
# Out:
# (([StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa7708f580>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#   [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa770ab670>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]),
#  RatioErrorbarArtists(line=<matplotlib.lines.Line2D object at 0x7faa7708f4f0>, errorbar=<ErrorbarContainer object of 3 artists>))

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]["genAs_toE_pt"][ch5,:150j].plot_ratio(
       output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]["genAs_toE_pt"][ch4,:150j], 
      rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm"
# Out:
# (([StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faaadec49d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#   [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa76c37130>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]),
#  RatioErrorbarArtists(line=<matplotlib.lines.Line2D object at 0x7faa76c2cfa0>, errorbar=<ErrorbarContainer object of 3 artists>))

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]["genAs_toE_pt"][ch7,:].plot_ratio(
       output["out"]["2Mu2E_200GeV_5GeV_200mm"]["hists"]["genAs_toE_pt"][ch6,:], 
      rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm"
# Out:
# (([StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa76ac4e20>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#   [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa76979220>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]),
#  RatioErrorbarArtists(line=<matplotlib.lines.Line2D object at 0x7faa76ac4c70>, errorbar=<ErrorbarContainer object of 3 artists>))

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]["genAs_toE_pt"][ch7,:].plot_ratio(
       output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]["genAs_toE_pt"][ch6,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm")
# Out:
# (([StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa76fb57f0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#   [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa8d303d00>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]),
#  RatioErrorbarArtists(line=<matplotlib.lines.Line2D object at 0x7faa99a9be80>, errorbar=<ErrorbarContainer object of 3 artists>))

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]["genAs_toE_pt"][ch3,:].plot_ratio(
       output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]["genAs_toE_pt"][ch2,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm")
# Out:
# (([StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa8cb3f760>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#   [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa8d1533a0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]),
#  RatioErrorbarArtists(line=<matplotlib.lines.Line2D object at 0x7faa8cb58f10>, errorbar=<ErrorbarContainer object of 3 artists>))

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]["genAs_toE_pt"][ch5,:].plot_ratio(
       output["out"]["2Mu2E_200GeV_1p2GeV_48mm"]["hists"]["genAs_toE_pt"][ch4,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm")
# Out:
# (([StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa766c8580>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#   [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa767013d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]),
#  RatioErrorbarArtists(line=<matplotlib.lines.Line2D object at 0x7faa766c82e0>, errorbar=<ErrorbarContainer object of 3 artists>))

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt"][ch7,:].plot_ratio(
       output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt"][ch6,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm")
# Out:
# (([StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa8c599dc0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#   [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa8d7bd4c0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]),
#  RatioErrorbarArtists(line=<matplotlib.lines.Line2D object at 0x7faa8d10b430>, errorbar=<ErrorbarContainer object of 3 artists>))

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt"][ch5,:].plot_ratio(
       output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt"][ch4,:], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm")
# Out:
# (([StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa77f24ca0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#   [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7faa77f36700>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]),
#  RatioErrorbarArtists(line=<matplotlib.lines.Line2D object at 0x7faa8d17f130>, errorbar=<ErrorbarContainer object of 3 artists>))

# %%
plt.figure(figsize=(10,10))
output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt"][ch3,40j:100j].plot_ratio(
       output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt"][ch2,40j:100j], 
       rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
       rp_denom_label=r"$Z_d \rightarrow ee $",
       rp_uncert_draw_type="line",
       rp_uncertainty_type="efficiency")
#plt.title("2Mu2E_100GeV_5GeV_4mm")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.figure(figsize=(10,10))
# ----> 2 output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt"][ch3,40j:100j].plot_ratio(
#       3        output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt"][ch2,40j:100j],
#       4        rp_num_label=r"$Z_d \rightarrow ee$ with $e\gamma$ LJ nearby",
#       5        rp_denom_label=r"$Z_d \rightarrow ee $",
#       6        rp_uncert_draw_type="line",
#       7        rp_uncertainty_type="efficiency")
#       8 #plt.title("2Mu2E_100GeV_5GeV_4mm")
#
# File /opt/conda/lib/python3.9/site-packages/hist/basehist.py:565, in BaseHist.plot_ratio(self, other, ax_dict, **kwargs)
#     556 """
#     557 ``plot_ratio`` method for ``BaseHist`` object.
#     558
#     559 Return a tuple of artists following a structure of
#     560 ``(main_ax_artists, subplot_ax_artists)``
#     561 """
#     563 from hist import plot
# --> 565 return plot._plot_ratiolike(
#     566     self, other, ax_dict=ax_dict, view="ratio", **kwargs
#     567 )
#
# File /opt/conda/lib/python3.9/site-packages/hist/plot.py:663, in _plot_ratiolike(self, other, likelihood, ax_dict, view, fit_fmt, **kwargs)
#     661 if view == "ratio":
#     662     ratios = hist_values / compare_values
# --> 663     ratio_uncert = ratio_uncertainty(
#     664         num=hist_values,
#     665         denom=compare_values,
#     666         uncertainty_type=rp_kwargs["uncertainty_type"],
#     667     )
#     668     # ratio: plot the ratios using Matplotlib errorbar or bar
#     669     subplot_ax_artists = plot_ratio_array(
#     670         self, ratios, ratio_uncert, ax=subplot_ax, **rp_kwargs
#     671     )
#
# File /opt/conda/lib/python3.9/site-packages/hist/intervals.py:162, in ratio_uncertainty(num, denom, uncertainty_type)
#     160         ratio_uncert = np.abs(r_lim - ratio)
#     161 elif uncertainty_type == "efficiency":
# --> 162     ratio_uncert = np.abs(clopper_pearson_interval(num, denom) - ratio)
#     163 else:
#     164     raise TypeError(
#     165         f"'{uncertainty_type}' is an invalid option for uncertainty_type."
#     166     )
#
# File /opt/conda/lib/python3.9/site-packages/hist/intervals.py:104, in clopper_pearson_interval(num, denom, coverage)
#     102 # Numerator is subset of denominator
#     103 if np.any(num > denom):
# --> 104     raise ValueError(
#     105         "Found numerator larger than denominator while calculating binomial uncertainty"
#     106     )
#     107 interval_min = stats.beta.ppf((1 - coverage) / 2, num, denom - num + 1)
#     108 interval_max = stats.beta.ppf((1 + coverage) / 2, num + 1, denom - num)
#
# ValueError: Found numerator larger than denominator while calculating binomial uncertainty

# %%
values = output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt_lxy_lowRange"][ch7,:, :].values()\
          /(output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt_lxy_lowRange"][ch6,:, :].values() + 0.00001)
hist2d = output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt_lxy_lowRange"][ch5,:, :]
#hist2d = hist.Hist(hist.axis.Regular(140, 0, 700), hist.axis.Regular(250, 0, 500))
fig, ax = plt.subplots()
#mesh = ax.pcolormesh(*hist2d.axes.edges.T, values.T)
mesh = ax.pcolormesh(*hist2d.axes.edges.T, values.T, vmin = 0.0 , vmax = 1.0)
ax.set_xlabel(r"$Z_d$ $p_T$")
ax.set_ylabel(r"$Z_d$ $L_{xy}$")
fig.colorbar(mesh)

# %%
values = output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt_EEdR_lowRange"][ch7,:, :].values()\
          /(output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt_EEdR_lowRange"][ch6,:, :].values() + 0.00001)
hist2d = output["out"]["2Mu2E_200GeV_0p25GeV_10mm"]["hists"]["genAs_toE_pt_EEdR_lowRange"][ch5,:, :]
#hist2d = hist.Hist(hist.axis.Regular(140, 0, 700), hist.axis.Regular(250, 0, 500))
fig, ax = plt.subplots()
#mesh = ax.pcolormesh(*hist2d.axes.edges.T, values.T)
mesh = ax.pcolormesh(*hist2d.axes.edges.T, values.T, vmin = 0.0 , vmax = 1.0)
ax.set_xlabel(r"$Z_d$ $p_T$")
ax.set_ylabel(r"$Z_d$ $L_{xy}$")
fig.colorbar(mesh)
