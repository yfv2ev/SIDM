#    "4mu_200GeV_1p2GeV_0p48mm",
#    "4mu_200GeV_1p2GeV_4p8mm",
#    "4mu_200GeV_1p2GeV_24p0mm",
#    "4mu_200GeV_1p2GeV_48p0mm",
    
#    "4mu_200GeV_5p0GeV_0p2mm",
#    "4mu_200GeV_5p0GeV_2p0mm",
#    "4mu_200GeV_5p0GeV_20p0mm",
#    "4mu_200GeV_5p0GeV_100p0mm",
#    "4mu_200GeV_5p0GeV_200p0mm",
    
#    "4mu_500GeV_0p25GeV_0p004mm",
#    "4mu_500GeV_0p25GeV_0p04mm",
#    "4mu_500GeV_0p25GeV_0p4mm",
#    "4mu_500GeV_0p25GeV_2p0mm",
#    "4mu_500GeV_0p25GeV_4p0mm",
    
#    "4mu_500GeV_1p2GeV_0p019mm",
#    "4mu_500GeV_1p2GeV_0p19mm",
#    "4mu_500GeV_1p2GeV_1p9mm",
#    "4mu_500GeV_1p2GeV_9p6mm",
#    "4mu_500GeV_1p2GeV_19p0mm",
    
#    "4mu_500GeV_5p0GeV_0p08mm",
#    "4mu_500GeV_5p0GeV_0p8mm",
#    "4mu_500GeV_5p0GeV_8p0mm",
#    "4mu_500GeV_5p0GeV_40p0mm",
#    "4mu_500GeV_5p0GeV_80p0mm",    
    
#    "4mu_800GeV_0p25GeV_0p0025mm",
#    "4mu_800GeV_0p25GeV_0p025mm",
#    "4mu_800GeV_0p25GeV_0p25mm",
#    "4mu_800GeV_0p25GeV_1p2mm",
#    "4mu_800GeV_0p25GeV_2p5mm",
    
#    "4mu_800GeV_1p2GeV_0p012mm",
#    "4mu_800GeV_1p2GeV_0p12mm",
#    "4mu_800GeV_1p2GeV_1p2mm",
#    "4mu_800GeV_1p2GeV_6p0mm",
#    "4mu_800GeV_1p2GeV_12p0mm",
    
#    "4mu_800GeV_5p0GeV_0p05mm",
#    "4mu_800GeV_5p0GeV_0p5mm",
#    "4mu_800GeV_5p0GeV_5p0mm",
#    "4mu_800GeV_5p0GeV_25p0mm",
#    "4mu_800GeV_5p0GeV_50p0mm",
    
#    "4mu_1000GeV_0p25GeV_0p002mm",
#    "4mu_1000GeV_0p25GeV_0p02mm",
#    "4mu_1000GeV_0p25GeV_0p2mm",
#    "4mu_1000GeV_0p25GeV_1p0mm",
#    "4mu_1000GeV_0p25GeV_2p0mm",

#    "4mu_1000GeV_1p2GeV_0p0096mm",
#    "4mu_1000GeV_1p2GeV_0p096mm",
#    "4mu_1000GeV_1p2GeV_0p96mm",
#    "4mu_1000GeV_1p2GeV_4p8mm",
#    "4mu_1000GeV_1p2GeV_9p6mm",

#    "4mu_1000GeV_5p0GeV_0p04mm",
#    "4mu_1000GeV_5p0GeV_0p4mm",
#    "4mu_1000GeV_5p0GeV_4p0mm",
#    "4mu_1000GeV_5p0GeV_20p0mm",
#    "4mu_1000GeV_5p0GeV_40p0mm",
    
    '2mu2e_500GeV_5p0GeV_0p08mm',
    '2mu2e_500GeV_5p0GeV_0p8mm',
    '2mu2e_500GeV_5p0GeV_8p0mm',
    '2mu2e_500GeV_5p0GeV_40p0mm',
    '2mu2e_500GeV_5p0GeV_80p0mm',
]

# %%
fileset = utilities.make_fileset(samples_4mu, "llpNanoAOD_v2")

runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=NanoAODSchema,
    #maxchunks=1,
)

channels = ["base", "2mu2e", "4mu"]
p = sidm_processor.SidmProcessor(
    channels,
    ["base"],
    lj_reco_choices=["0.4"],
    llpnanoaod=True,
)

output = runner.run(fileset, treename="Events", processor_instance=p)
out = output["out"]
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 18
#      10 channels = ["base", "2mu2e", "4mu"]
#      11 p = sidm_processor.SidmProcessor(
#      12     channels,
#      13     ["base"],
#      14     lj_reco_choices=["0.4"],
#      15     llpnanoaod=True,
#      16 )
# ---> 18 output = runner.run(fileset, treename="Events", processor_instance=p)
#      19 out = output["out"]
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/executor.py:1782, in Runner.run(self, fileset, processor_instance, treename)
#    1780     chunks = fileset
#    1781 else:
# -> 1782     chunks = self.preprocess(fileset, treename)
#    1784 if self.processor_compression is None:
#    1785     pi_to_send = processor_instance
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/executor.py:1734, in Runner.preprocess(self, fileset, treename)
#    1731 for filemeta in fileset:
#    1732     filemeta.maybe_populate(self.metadata_cache)
# -> 1734 self._preprocess_fileset(fileset)
#    1735 fileset = self._filter_badfiles(fileset)
#    1737 # reverse fileset list to match the order of files as presented in version
#    1738 # v0.7.4. This fixes tests using maxchunks.
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/executor.py:1461, in Runner._preprocess_fileset(self, fileset)
#    1454 pre_executor = self.pre_executor.copy(**pre_arg_override)
#    1455 closure = partial(
#    1456     self.automatic_retries,
#    1457     self.retries,
#    1458     self.skipbadfiles,
#    1459     partial(self.metadata_fetcher, self.xrootdtimeout, self.align_clusters),
#    1460 )
# -> 1461 out, _ = pre_executor(to_get, closure, out)
#    1462 while out:
#    1463     item = out.pop()
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/executor.py:672, in IterativeExecutor.__call__(self, items, function, accumulator)
#     667 with rich_bar() as progress:
#     668     p_id = progress.add_task(
#     669         self.desc, total=len(items), unit=self.unit, disable=not self.status
#     670     )
#     671     return (
# --> 672         accumulate(
#     673             progress.track(
#     674                 map(function, (c for c in items)),
#     675                 total=len(items),
#     676                 task_id=p_id,
#     677             ),
#     678             accumulator,
#     679         ),
#     680         0,
#     681     )
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/accumulator.py:100, in accumulate(items, accum)
#      97         accum = add(accum, next(gen))
#      98     while True:
#      99         # subsequent additions can happen in-place, which may be more performant
# --> 100         accum = iadd(accum, next(gen))
#     101 except StopIteration:
#     102     pass
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/accumulator.py:92, in <genexpr>(.0)
#      89 def accumulate(
#      90     items: Iterable[Optional[Accumulatable]], accum: Optional[Accumulatable] = None
#      91 ) -> Optional[Accumulatable]:
# ---> 92     gen = (x for x in items if x is not None)
#      93     try:
#      94         if accum is None:
#
# File /opt/conda/lib/python3.9/site-packages/rich/progress.py:1215, in Progress.track(self, sequence, total, task_id, description, update_period)
#    1213 advance = self.advance
#    1214 refresh = self.refresh
# -> 1215 for value in sequence:
#    1216     yield value
#    1217     advance(task_id, 1)
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/executor.py:1367, in Runner.automatic_retries(retries, skipbadfiles, func, *args, **kwargs)
#    1361         break
#    1362     if (
#    1363         not skipbadfiles
#    1364         or any("Auth failed" in str(c) for c in chain)
#    1365         or retries == retry_count
#    1366     ):
# -> 1367         raise e
#    1368     warnings.warn("Attempt %d of %d." % (retry_count + 1, retries + 1))
#    1369 retry_count += 1
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/executor.py:1336, in Runner.automatic_retries(retries, skipbadfiles, func, *args, **kwargs)
#    1334 while retry_count <= retries:
#    1335     try:
# -> 1336         return func(*args, **kwargs)
#    1337     # catch xrootd errors and optionally skip
#    1338     # or retry to read the file
#    1339     except Exception as e:
#
# File /opt/conda/lib/python3.9/site-packages/coffea/processor/executor.py:1417, in Runner.metadata_fetcher(xrootdtimeout, align_clusters, item)
#    1413 @staticmethod
#    1414 def metadata_fetcher(
#    1415     xrootdtimeout: int, align_clusters: bool, item: FileMeta
#    1416 ) -> Accumulatable:
# -> 1417     with uproot.open({item.filename: None}, timeout=xrootdtimeout) as file:
#    1418         try:
#    1419             tree = file[item.treename]
#
# File /opt/conda/lib/python3.9/site-packages/uproot/reading.py:141, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     132 if not uproot._util.isstr(file_path) and not (
#     133     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     134 ):
#     135     raise ValueError(
#     136         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     137         "'seek' methods, or a length-1 dict of {{file_path: object_path}}, "
#     138         "not {0}".format(repr(path))
#     139     )
# --> 141 file = ReadOnlyFile(
#     142     file_path,
#     143     object_cache=object_cache,
#     144     array_cache=array_cache,
#     145     custom_classes=custom_classes,
#     146     decompression_executor=decompression_executor,
#     147     interpretation_executor=interpretation_executor,
#     148     **options,  # NOTE: a comma after **options breaks Python 2
#     149 )
#     151 if object_path is None:
#     152     return file.root_directory
#
# File /opt/conda/lib/python3.9/site-packages/uproot/reading.py:580, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     575 self.hook_before_create_source()
#     577 Source, file_path = uproot._util.file_path_to_source_class(
#     578     file_path, self._options
#     579 )
# --> 580 self._source = Source(
#     581     file_path, **self._options  # NOTE: a comma after **options breaks Python 2
#     582 )
#     584 self.hook_before_get_chunks()
#     586 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#
# File /opt/conda/lib/python3.9/site-packages/uproot/source/xrootd.py:272, in XRootDSource.__init__(self, file_path, **options)
#     270 self._file_path = file_path
#     271 self._num_bytes = None
# --> 272 self._open()
#
# File /opt/conda/lib/python3.9/site-packages/uproot/source/xrootd.py:275, in XRootDSource._open(self)
#     274 def _open(self):
# --> 275     self._resource = XRootDResource(self._file_path, self._timeout)
#     277     # this ThreadPool does not need a resource, it's only used to submit
#     278     # futures that wait for chunks that have been split to merge them.
#     279     self._executor = uproot.source.futures.ResourceThreadPoolExecutor(
#     280         [None for i in range(self._num_workers)]
#     281     )
#
# File /opt/conda/lib/python3.9/site-packages/uproot/source/xrootd.py:83, in XRootDResource.__init__(self, file_path, timeout)
#      81 self._file_path = file_path
#      82 self._timeout = timeout
# ---> 83 self._open()
#
# File /opt/conda/lib/python3.9/site-packages/uproot/source/xrootd.py:92, in XRootDResource._open(self)
#      90 status, dummy = self._file.open(self._file_path, timeout=self._xrd_timeout())
#      91 if status.error:
# ---> 92     self._xrd_error(status)
#
# File /opt/conda/lib/python3.9/site-packages/uproot/source/xrootd.py:118, in XRootDResource._xrd_error(self, status)
#     115             raise uproot._util._file_not_found(self._file_path, status.message)
#     117         else:
# --> 118             raise OSError(
#     119                 """XRootD error: {}
#     120 in file {}""".format(
#     121                     status.message, self._file_path
#     122                 )
#     123             )
#
# OSError: XRootD error: [ERROR] Operation expired
# in file root://xcache//store/group/lpcmetx/SIDM/ULSignalSamples/2018_v6/LLPNanoAOD_V2/SIDM_BsTo2DpTo2Mu2e_MBs-500_MDp-5p0_ctau-40p0/LLPnanoAODv2/SIDM_BsTo2DpTo2Mu2e_MBs-500_MDp-5p0_ctau-40p0_part-1.root
